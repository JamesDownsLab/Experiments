# %%
from particletracking import dataframes

# %%
data = dataframes.DataStore("/media/data/Data/FirstOrder/Hysterisis/5Repeats/RedTray/0.1_down_3.hdf5")

# %%
data.df
# Out:
#           x     y   r        Duty   order_r   order_i  neighbors     order  \
# frame
# 0       639  1043  17  700.666667  0.756483  0.087189          4  0.761491
# 0       811   884  17  700.666667 -0.402674  0.777303          4  0.875412
# 0      1531  1639  17  700.666667  0.999643  0.026713          1  1.000000
# 0       483   880  17  700.666667  0.433993  0.900916          1  1.000000
# 0      1637  1199  17  700.666667 -0.506353  0.669414          5  0.839350
# ...     ...   ...  ..         ...       ...       ...        ...       ...
# 51023  1801   468  18  600.000000  0.987618  0.156876          1  1.000000
# 51023  1360  1775  17  600.000000  0.567609  0.062037          2  0.570989
# 51023   862   112  17  600.000000 -0.142139  0.026226          5  0.144538
# 51023   169   626  18  600.000000  0.677604  0.735427          1  1.000000
# 51023   514  1764  17  600.000000  0.875502  0.305106          2  0.927143
#
#         density  shape_factor  on_edge  edge_distance
# ...

# %%
data.df.loc[51023]
# Out:
#           x     y   r   Duty   order_r   order_i  neighbors     order  \
# frame
# 51023   526  1165  17  600.0 -0.904566 -0.208373          5  0.928256
# 51023   822   640  17  600.0 -0.863736 -0.222859          6  0.892023
# 51023   226   966  17  600.0  0.431277 -0.880226          2  0.980202
# 51023   790  1203  17  600.0 -0.967089 -0.096832          6  0.971924
# 51023   831   266  17  600.0 -0.912869  0.195286          6  0.933524
# ...     ...   ...  ..    ...       ...       ...        ...       ...
# 51023  1801   468  18  600.0  0.987618  0.156876          1  1.000000
# 51023  1360  1775  17  600.0  0.567609  0.062037          2  0.570989
# 51023   862   112  17  600.0 -0.142139  0.026226          5  0.144538
# 51023   169   626  18  600.0  0.677604  0.735427          1  1.000000
# 51023   514  1764  17  600.0  0.875502  0.305106          2  0.927143
#
#         density  shape_factor  on_edge  edge_distance
# frame
# 51023  0.838270      1.119215    False     317.207611
# ...

# %%
2191*12.57/41916
# Out:
# 0.6570490981963928

# %%
2263*12.57/33765
# Out:
# 0.842467347845402

# %%
from ...duty import d2G
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-512355f614b3> in <module>
# ----> 1 from ...duty import d2G
#
# ImportError: attempted relative import with no known parent package

# %%
g = 9.81
v2a = 42.46

def d2a(d):
    """Converts duty cycle to acceleration ms^-2"""
    a = v2a * 0.003 * d - v2a * 1.5
    return a

def d2G(d):
    """Converts duty cycle to dimensionless acceleration"""
    return d2a(d) / g

# %%
d2G(700)
# Out:
# 2.5969418960244646

# %%
d2G(600)
# Out:
# 1.2984709480122323

# %%
data = dataframes.DataStore("/media/data/Data/FirstOrder/Hysterisis/5Repeats/RedTrayDense/0.1_down_1.hdf5")

# %%
data.df.loc[50999]
# Out:
#           x     y   r        Duty   order_r   order_i  neighbors     order  \
# frame
# 50999   661  1109  17  599.933333 -0.829168  0.172941          5  0.847012
# 50999   719  1402  17  599.933333 -0.867811 -0.397314          6  0.954440
# 50999   923   412  17  599.933333 -0.980430 -0.035577          4  0.981075
# 50999  1643  1068  17  599.933333 -0.872733 -0.172362          6  0.889591
# 50999   984   821  17  599.933333 -0.971695  0.064787          6  0.973852
# ...     ...   ...  ..         ...       ...       ...        ...       ...
# 50999  1006    16  18  599.933333  0.947318  0.317064          3  0.998970
# 50999   430   188  18  599.933333  0.899373 -0.177092          3  0.916642
# 50999   337  1465  18  599.933333  0.666330  0.645287          2  0.927573
# 50999   306   793  17  599.933333 -0.560340 -0.002327          5  0.560345
# 50999  1864   729  18  599.933333 -0.037599  0.088522          4  0.096177
#
# ...

# %%
r1 = (d2G(700)-d2G(600))/(100/0.4)
r1
# Out:
# 0.005193883792048929

# %%
r2 = (d2G(700)-d2G(600))/(100/0.2)
r2
# Out:
# 0.0025969418960244644

# %%
d2G(630)
# Out:
# 1.6880122324159017
