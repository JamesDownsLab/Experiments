# %%
import pandas as pd

# %%
data = pd.read_csv("/media/NAS/share/James/SimulationDataSep22/87_3,5e-4_savedata.hdf5")

# %%
data.tail()
# Out:
#           Unnamed: 0   frame     v_hoz  v_hoz_10000_Hz  v_hoz_2000_Hz  \
# 20399995    20399995  400000  0.046031        0.045890       0.039276
# 20399996    20399996  400000  0.053191        0.046584       0.031872
# 20399997    20399997  400000  0.024950        0.022908       0.017858
# 20399998    20399998  400000  0.103357        0.103362       0.103357
# 20399999    20399999  400000  0.064038        0.064040       0.064038
#
#           v_hoz_1000_Hz  v_hoz_200_Hz  v_hoz_100_Hz  v_hoz_20_Hz  v_hoz_10_Hz
# 20399995       0.034720      0.030256      0.022988     0.022445     0.052523
# 20399996       0.040157      0.055652      0.057778     0.052216     0.071042
# 20399997       0.016575      0.002805      0.014866     0.008149     1.964017
# 20399998       0.103357      0.103357      0.103357     0.016015     0.009265
# 20399999       0.064038      0.064042      0.064938     0.040150     0.020878

# %%
frame_medians = data.groupby('frame').median()
frame_medians = frame_medians.drop('Unnamed: 0', axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-3e745107964d> in <module>
#       1 frame_medians = data.groupby('frame').median()
#       2 frame_medians = frame_medians.drop('Unnamed: 0', axis=1)
# ----> 3 frame_medians.size()
#
# TypeError: 'numpy.int64' object is not callable

# %%
frame_medians.memory_usage().sum()/1000 , 'KB'
# Out:
# (720.0, 'KB')

# %%
frame_medians.plot()
# Out:
# <AxesSubplot:xlabel='frame'>

# %%
frame_medians['v_hoz'] - frame_medians['v_hoz_10000_Hz']
# Out:
# frame
# 300010         NaN
# 300020   -0.000197
# 300030   -0.000378
# 300040   -0.000079
# 300050   -0.000225
#             ...
# 399960    0.000003
# 399970   -0.000239
# 399980   -0.000316
# 399990   -0.000035
# 400000    0.000016
# Length: 10000, dtype: float64

# %%
frequencies = frame_medians.mean().index
frequencies = [int(x) if len(f) == 4 else ]
# Out:
# ['v_hoz',
#  'v_hoz_10000_Hz',
#  'v_hoz_2000_Hz',
#  'v_hoz_1000_Hz',
#  'v_hoz_200_Hz',
#  'v_hoz_100_Hz',
#  'v_hoz_20_Hz',
#  'v_hoz_10_Hz']

# %%
frame_medians.mean().plot()
# Out:
# <AxesSubplot:>
